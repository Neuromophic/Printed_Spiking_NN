# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('../result/Vout_ACT_interactive1.csv')
data
# Out:
#       Vinput(V)  1_Vout(V)  2_Vout(V)  3_Vout(V)  4_Vout(V)  5_Vout(V)  \
# 0        -2.000    -0.8860    -0.8800    -0.8530    -0.8780    -0.8190
# 1        -1.999    -0.8860    -0.8800    -0.8530    -0.8780    -0.8190
# 2        -1.998    -0.8860    -0.8800    -0.8530    -0.8780    -0.8190
# 3        -1.997    -0.8860    -0.8800    -0.8530    -0.8780    -0.8190
# 4        -1.996    -0.8860    -0.8800    -0.8530    -0.8780    -0.8190
# ...         ...        ...        ...        ...        ...        ...
# 3996      1.996     0.9999     0.9999     0.9999     0.9999     0.9999
# 3997      1.997     0.9999     0.9999     0.9999     0.9999     0.9999
# 3998      1.998     0.9999     0.9999     0.9999     0.9999     0.9999
# 3999      1.999     0.9999     0.9999     0.9999     0.9999     0.9999
# 4000      2.000     0.9999     0.9999     0.9999     0.9999     0.9999
#
#       6_Vout(V)  7_Vout(V)  8_Vout(V)  9_Vout(V)  ...  9991_Vout(V)  \
# ...

# %%
a = data.iloc[:,1:].to_numpy().T
a.shape
# Out:
# (10000, 4001)

# %%
np.savetxt('./data/act_output.csv', a, fmt='%f', delimiter=',')
