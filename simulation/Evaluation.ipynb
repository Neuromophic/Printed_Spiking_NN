# %%
import sys
import os
from pathlib import Path
import torch
sys.path.append(os.getcwd())
sys.path.append(str(Path(os.getcwd()).parent))
from utils import *
from configuration import *
import numpy as np

if not os.path.exists('./evaluation/'):
    os.makedirs('./evaluation/')

# %%
args = parser.parse_args([])
args.task = 'temporal'
args.metric = 'temporal_acc'
args.SoftEva = True
args = FormulateArgs(args)

# %%
results = torch.zeros([40,10,2])

for seed in range(10):
    for ds in range(40):
        args.SEED = seed
        args.DATASET = ds

        valid_loader, datainfo = GetDataLoader(args, 'valid', path='../dataset/')
        test_loader , datainfo = GetDataLoader(args, 'test',  path='../dataset/')

        modelname = f"pLF_data_{args.DATASET:02d}_{datainfo['dataname']}_seed_{args.SEED:02d}.model"
        print(modelname)
        
        if os.path.isfile(f'./models/{modelname}'):                
            model = torch.load(f'./models/{modelname}', map_location=args.DEVICE)

            SetSeed(args.SEED)

            evaluator = Evaluator(args).to(args.DEVICE)

            for x,y in valid_loader:
                X_valid, y_valid = x.to(args.DEVICE), y.to(args.DEVICE)
            for x,y in test_loader:
                X_test, y_test = x.to(args.DEVICE), y.to(args.DEVICE)

            acc_valid = evaluator(model, X_valid, y_valid)
            acc_test   = evaluator(model, X_test,  y_test)

            results[ds,seed,0] = acc_valid
            results[ds,seed,1] = acc_test
        else:
            results[ds,seed,:] = float('nan')
# Out:
# pLF_data_00_cbf_seed_00.model
# pLF_data_01_diatomsizereduction_seed_00.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_00.model
# pLF_data_03_distalphalanxtw_seed_00.model
# pLF_data_04_earthquakes_seed_00.model
# pLF_data_05_ecg5000_seed_00.model
# pLF_data_06_ecgfivedays_seed_00.model
# pLF_data_07_fordb_seed_00.model
# pLF_data_08_freezerregulartrain_seed_00.model
# pLF_data_09_freezersmalltrain_seed_00.model
# pLF_data_10_gunpoint_seed_00.model
# pLF_data_11_gunpointagespan_seed_00.model
# pLF_data_12_gunpointmaleversusfemale_seed_00.model
# pLF_data_13_gunpointoldversusyoung_seed_00.model
# pLF_data_14_ham_seed_00.model
# pLF_data_15_handoutlines_seed_00.model
# pLF_data_16_insectepgregulartrain_seed_00.model
# pLF_data_17_insectepgsmalltrain_seed_00.model
# pLF_data_18_italypowerdemand_seed_00.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_00.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_00.model
# pLF_data_21_middlephalanxtw_seed_00.model
# pLF_data_22_mixedshapesregulartrain_seed_00.model
# pLF_data_23_motestrain_seed_00.model
# pLF_data_24_phalangesoutlinescorrect_seed_00.model
# pLF_data_25_plane_seed_00.model
# pLF_data_26_powercons_seed_00.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_00.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_00.model
# pLF_data_29_proximalphalanxtw_seed_00.model
# pLF_data_30_selfregulationscp1_seed_00.model
# pLF_data_31_slope_seed_00.model
# pLF_data_32_smoothsubspace_seed_00.model
# pLF_data_33_sonyaiborobotsurface1_seed_00.model
# pLF_data_34_sonyaiborobotsurface2_seed_00.model
# pLF_data_35_starlightcurves_seed_00.model
# pLF_data_36_strawberry_seed_00.model
# pLF_data_37_symbols_seed_00.model
# pLF_data_38_twoleadecg_seed_00.model
# pLF_data_39_wafer_seed_00.model
# pLF_data_00_cbf_seed_01.model
# pLF_data_01_diatomsizereduction_seed_01.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_01.model
# pLF_data_03_distalphalanxtw_seed_01.model
# pLF_data_04_earthquakes_seed_01.model
# pLF_data_05_ecg5000_seed_01.model
# pLF_data_06_ecgfivedays_seed_01.model
# pLF_data_07_fordb_seed_01.model
# pLF_data_08_freezerregulartrain_seed_01.model
# pLF_data_09_freezersmalltrain_seed_01.model
# pLF_data_10_gunpoint_seed_01.model
# pLF_data_11_gunpointagespan_seed_01.model
# pLF_data_12_gunpointmaleversusfemale_seed_01.model
# pLF_data_13_gunpointoldversusyoung_seed_01.model
# pLF_data_14_ham_seed_01.model
# pLF_data_15_handoutlines_seed_01.model
# pLF_data_16_insectepgregulartrain_seed_01.model
# pLF_data_17_insectepgsmalltrain_seed_01.model
# pLF_data_18_italypowerdemand_seed_01.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_01.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_01.model
# pLF_data_21_middlephalanxtw_seed_01.model
# pLF_data_22_mixedshapesregulartrain_seed_01.model
# pLF_data_23_motestrain_seed_01.model
# pLF_data_24_phalangesoutlinescorrect_seed_01.model
# pLF_data_25_plane_seed_01.model
# pLF_data_26_powercons_seed_01.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_01.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_01.model
# pLF_data_29_proximalphalanxtw_seed_01.model
# pLF_data_30_selfregulationscp1_seed_01.model
# pLF_data_31_slope_seed_01.model
# pLF_data_32_smoothsubspace_seed_01.model
# pLF_data_33_sonyaiborobotsurface1_seed_01.model
# pLF_data_34_sonyaiborobotsurface2_seed_01.model
# pLF_data_35_starlightcurves_seed_01.model
# pLF_data_36_strawberry_seed_01.model
# pLF_data_37_symbols_seed_01.model
# pLF_data_38_twoleadecg_seed_01.model
# pLF_data_39_wafer_seed_01.model
# pLF_data_00_cbf_seed_02.model
# pLF_data_01_diatomsizereduction_seed_02.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_02.model
# pLF_data_03_distalphalanxtw_seed_02.model
# pLF_data_04_earthquakes_seed_02.model
# pLF_data_05_ecg5000_seed_02.model
# pLF_data_06_ecgfivedays_seed_02.model
# pLF_data_07_fordb_seed_02.model
# pLF_data_08_freezerregulartrain_seed_02.model
# pLF_data_09_freezersmalltrain_seed_02.model
# pLF_data_10_gunpoint_seed_02.model
# pLF_data_11_gunpointagespan_seed_02.model
# pLF_data_12_gunpointmaleversusfemale_seed_02.model
# pLF_data_13_gunpointoldversusyoung_seed_02.model
# pLF_data_14_ham_seed_02.model
# pLF_data_15_handoutlines_seed_02.model
# pLF_data_16_insectepgregulartrain_seed_02.model
# pLF_data_17_insectepgsmalltrain_seed_02.model
# pLF_data_18_italypowerdemand_seed_02.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_02.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_02.model
# pLF_data_21_middlephalanxtw_seed_02.model
# pLF_data_22_mixedshapesregulartrain_seed_02.model
# pLF_data_23_motestrain_seed_02.model
# pLF_data_24_phalangesoutlinescorrect_seed_02.model
# pLF_data_25_plane_seed_02.model
# pLF_data_26_powercons_seed_02.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_02.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_02.model
# pLF_data_29_proximalphalanxtw_seed_02.model
# pLF_data_30_selfregulationscp1_seed_02.model
# pLF_data_31_slope_seed_02.model
# pLF_data_32_smoothsubspace_seed_02.model
# pLF_data_33_sonyaiborobotsurface1_seed_02.model
# pLF_data_34_sonyaiborobotsurface2_seed_02.model
# pLF_data_35_starlightcurves_seed_02.model
# pLF_data_36_strawberry_seed_02.model
# pLF_data_37_symbols_seed_02.model
# pLF_data_38_twoleadecg_seed_02.model
# pLF_data_39_wafer_seed_02.model
# pLF_data_00_cbf_seed_03.model
# pLF_data_01_diatomsizereduction_seed_03.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_03.model
# pLF_data_03_distalphalanxtw_seed_03.model
# pLF_data_04_earthquakes_seed_03.model
# pLF_data_05_ecg5000_seed_03.model
# pLF_data_06_ecgfivedays_seed_03.model
# pLF_data_07_fordb_seed_03.model
# pLF_data_08_freezerregulartrain_seed_03.model
# pLF_data_09_freezersmalltrain_seed_03.model
# pLF_data_10_gunpoint_seed_03.model
# pLF_data_11_gunpointagespan_seed_03.model
# pLF_data_12_gunpointmaleversusfemale_seed_03.model
# pLF_data_13_gunpointoldversusyoung_seed_03.model
# pLF_data_14_ham_seed_03.model
# pLF_data_15_handoutlines_seed_03.model
# pLF_data_16_insectepgregulartrain_seed_03.model
# pLF_data_17_insectepgsmalltrain_seed_03.model
# pLF_data_18_italypowerdemand_seed_03.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_03.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_03.model
# pLF_data_21_middlephalanxtw_seed_03.model
# pLF_data_22_mixedshapesregulartrain_seed_03.model
# pLF_data_23_motestrain_seed_03.model
# pLF_data_24_phalangesoutlinescorrect_seed_03.model
# pLF_data_25_plane_seed_03.model
# pLF_data_26_powercons_seed_03.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_03.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_03.model
# pLF_data_29_proximalphalanxtw_seed_03.model
# pLF_data_30_selfregulationscp1_seed_03.model
# pLF_data_31_slope_seed_03.model
# pLF_data_32_smoothsubspace_seed_03.model
# pLF_data_33_sonyaiborobotsurface1_seed_03.model
# pLF_data_34_sonyaiborobotsurface2_seed_03.model
# pLF_data_35_starlightcurves_seed_03.model
# pLF_data_36_strawberry_seed_03.model
# pLF_data_37_symbols_seed_03.model
# pLF_data_38_twoleadecg_seed_03.model
# pLF_data_39_wafer_seed_03.model
# pLF_data_00_cbf_seed_04.model
# pLF_data_01_diatomsizereduction_seed_04.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_04.model
# pLF_data_03_distalphalanxtw_seed_04.model
# pLF_data_04_earthquakes_seed_04.model
# pLF_data_05_ecg5000_seed_04.model
# pLF_data_06_ecgfivedays_seed_04.model
# pLF_data_07_fordb_seed_04.model
# pLF_data_08_freezerregulartrain_seed_04.model
# pLF_data_09_freezersmalltrain_seed_04.model
# pLF_data_10_gunpoint_seed_04.model
# pLF_data_11_gunpointagespan_seed_04.model
# pLF_data_12_gunpointmaleversusfemale_seed_04.model
# pLF_data_13_gunpointoldversusyoung_seed_04.model
# pLF_data_14_ham_seed_04.model
# pLF_data_15_handoutlines_seed_04.model
# pLF_data_16_insectepgregulartrain_seed_04.model
# pLF_data_17_insectepgsmalltrain_seed_04.model
# pLF_data_18_italypowerdemand_seed_04.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_04.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_04.model
# pLF_data_21_middlephalanxtw_seed_04.model
# pLF_data_22_mixedshapesregulartrain_seed_04.model
# pLF_data_23_motestrain_seed_04.model
# pLF_data_24_phalangesoutlinescorrect_seed_04.model
# pLF_data_25_plane_seed_04.model
# pLF_data_26_powercons_seed_04.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_04.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_04.model
# pLF_data_29_proximalphalanxtw_seed_04.model
# pLF_data_30_selfregulationscp1_seed_04.model
# pLF_data_31_slope_seed_04.model
# pLF_data_32_smoothsubspace_seed_04.model
# pLF_data_33_sonyaiborobotsurface1_seed_04.model
# pLF_data_34_sonyaiborobotsurface2_seed_04.model
# pLF_data_35_starlightcurves_seed_04.model
# pLF_data_36_strawberry_seed_04.model
# pLF_data_37_symbols_seed_04.model
# pLF_data_38_twoleadecg_seed_04.model
# pLF_data_39_wafer_seed_04.model
# pLF_data_00_cbf_seed_05.model
# pLF_data_01_diatomsizereduction_seed_05.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_05.model
# pLF_data_03_distalphalanxtw_seed_05.model
# pLF_data_04_earthquakes_seed_05.model
# pLF_data_05_ecg5000_seed_05.model
# pLF_data_06_ecgfivedays_seed_05.model
# pLF_data_07_fordb_seed_05.model
# pLF_data_08_freezerregulartrain_seed_05.model
# pLF_data_09_freezersmalltrain_seed_05.model
# pLF_data_10_gunpoint_seed_05.model
# pLF_data_11_gunpointagespan_seed_05.model
# pLF_data_12_gunpointmaleversusfemale_seed_05.model
# pLF_data_13_gunpointoldversusyoung_seed_05.model
# pLF_data_14_ham_seed_05.model
# pLF_data_15_handoutlines_seed_05.model
# pLF_data_16_insectepgregulartrain_seed_05.model
# pLF_data_17_insectepgsmalltrain_seed_05.model
# pLF_data_18_italypowerdemand_seed_05.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_05.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_05.model
# pLF_data_21_middlephalanxtw_seed_05.model
# pLF_data_22_mixedshapesregulartrain_seed_05.model
# pLF_data_23_motestrain_seed_05.model
# pLF_data_24_phalangesoutlinescorrect_seed_05.model
# pLF_data_25_plane_seed_05.model
# pLF_data_26_powercons_seed_05.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_05.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_05.model
# pLF_data_29_proximalphalanxtw_seed_05.model
# pLF_data_30_selfregulationscp1_seed_05.model
# pLF_data_31_slope_seed_05.model
# pLF_data_32_smoothsubspace_seed_05.model
# pLF_data_33_sonyaiborobotsurface1_seed_05.model
# pLF_data_34_sonyaiborobotsurface2_seed_05.model
# pLF_data_35_starlightcurves_seed_05.model
# pLF_data_36_strawberry_seed_05.model
# pLF_data_37_symbols_seed_05.model
# pLF_data_38_twoleadecg_seed_05.model
# pLF_data_39_wafer_seed_05.model
# pLF_data_00_cbf_seed_06.model
# pLF_data_01_diatomsizereduction_seed_06.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_06.model
# pLF_data_03_distalphalanxtw_seed_06.model
# pLF_data_04_earthquakes_seed_06.model
# pLF_data_05_ecg5000_seed_06.model
# pLF_data_06_ecgfivedays_seed_06.model
# pLF_data_07_fordb_seed_06.model
# pLF_data_08_freezerregulartrain_seed_06.model
# pLF_data_09_freezersmalltrain_seed_06.model
# pLF_data_10_gunpoint_seed_06.model
# pLF_data_11_gunpointagespan_seed_06.model
# pLF_data_12_gunpointmaleversusfemale_seed_06.model
# pLF_data_13_gunpointoldversusyoung_seed_06.model
# pLF_data_14_ham_seed_06.model
# pLF_data_15_handoutlines_seed_06.model
# pLF_data_16_insectepgregulartrain_seed_06.model
# pLF_data_17_insectepgsmalltrain_seed_06.model
# pLF_data_18_italypowerdemand_seed_06.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_06.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_06.model
# pLF_data_21_middlephalanxtw_seed_06.model
# pLF_data_22_mixedshapesregulartrain_seed_06.model
# pLF_data_23_motestrain_seed_06.model
# pLF_data_24_phalangesoutlinescorrect_seed_06.model
# pLF_data_25_plane_seed_06.model
# pLF_data_26_powercons_seed_06.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_06.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_06.model
# pLF_data_29_proximalphalanxtw_seed_06.model
# pLF_data_30_selfregulationscp1_seed_06.model
# pLF_data_31_slope_seed_06.model
# pLF_data_32_smoothsubspace_seed_06.model
# pLF_data_33_sonyaiborobotsurface1_seed_06.model
# pLF_data_34_sonyaiborobotsurface2_seed_06.model
# pLF_data_35_starlightcurves_seed_06.model
# pLF_data_36_strawberry_seed_06.model
# pLF_data_37_symbols_seed_06.model
# pLF_data_38_twoleadecg_seed_06.model
# pLF_data_39_wafer_seed_06.model
# pLF_data_00_cbf_seed_07.model
# pLF_data_01_diatomsizereduction_seed_07.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_07.model
# pLF_data_03_distalphalanxtw_seed_07.model
# pLF_data_04_earthquakes_seed_07.model
# pLF_data_05_ecg5000_seed_07.model
# pLF_data_06_ecgfivedays_seed_07.model
# pLF_data_07_fordb_seed_07.model
# pLF_data_08_freezerregulartrain_seed_07.model
# pLF_data_09_freezersmalltrain_seed_07.model
# pLF_data_10_gunpoint_seed_07.model
# pLF_data_11_gunpointagespan_seed_07.model
# pLF_data_12_gunpointmaleversusfemale_seed_07.model
# pLF_data_13_gunpointoldversusyoung_seed_07.model
# pLF_data_14_ham_seed_07.model
# pLF_data_15_handoutlines_seed_07.model
# pLF_data_16_insectepgregulartrain_seed_07.model
# pLF_data_17_insectepgsmalltrain_seed_07.model
# pLF_data_18_italypowerdemand_seed_07.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_07.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_07.model
# pLF_data_21_middlephalanxtw_seed_07.model
# pLF_data_22_mixedshapesregulartrain_seed_07.model
# pLF_data_23_motestrain_seed_07.model
# pLF_data_24_phalangesoutlinescorrect_seed_07.model
# pLF_data_25_plane_seed_07.model
# pLF_data_26_powercons_seed_07.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_07.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_07.model
# pLF_data_29_proximalphalanxtw_seed_07.model
# pLF_data_30_selfregulationscp1_seed_07.model
# pLF_data_31_slope_seed_07.model
# pLF_data_32_smoothsubspace_seed_07.model
# pLF_data_33_sonyaiborobotsurface1_seed_07.model
# pLF_data_34_sonyaiborobotsurface2_seed_07.model
# pLF_data_35_starlightcurves_seed_07.model
# pLF_data_36_strawberry_seed_07.model
# pLF_data_37_symbols_seed_07.model
# pLF_data_38_twoleadecg_seed_07.model
# pLF_data_39_wafer_seed_07.model
# pLF_data_00_cbf_seed_08.model
# pLF_data_01_diatomsizereduction_seed_08.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_08.model
# pLF_data_03_distalphalanxtw_seed_08.model
# pLF_data_04_earthquakes_seed_08.model
# pLF_data_05_ecg5000_seed_08.model
# pLF_data_06_ecgfivedays_seed_08.model
# pLF_data_07_fordb_seed_08.model
# pLF_data_08_freezerregulartrain_seed_08.model
# pLF_data_09_freezersmalltrain_seed_08.model
# pLF_data_10_gunpoint_seed_08.model
# pLF_data_11_gunpointagespan_seed_08.model
# pLF_data_12_gunpointmaleversusfemale_seed_08.model
# pLF_data_13_gunpointoldversusyoung_seed_08.model
# pLF_data_14_ham_seed_08.model
# pLF_data_15_handoutlines_seed_08.model
# pLF_data_16_insectepgregulartrain_seed_08.model
# pLF_data_17_insectepgsmalltrain_seed_08.model
# pLF_data_18_italypowerdemand_seed_08.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_08.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_08.model
# pLF_data_21_middlephalanxtw_seed_08.model
# pLF_data_22_mixedshapesregulartrain_seed_08.model
# pLF_data_23_motestrain_seed_08.model
# pLF_data_24_phalangesoutlinescorrect_seed_08.model
# pLF_data_25_plane_seed_08.model
# pLF_data_26_powercons_seed_08.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_08.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_08.model
# pLF_data_29_proximalphalanxtw_seed_08.model
# pLF_data_30_selfregulationscp1_seed_08.model
# pLF_data_31_slope_seed_08.model
# pLF_data_32_smoothsubspace_seed_08.model
# pLF_data_33_sonyaiborobotsurface1_seed_08.model
# pLF_data_34_sonyaiborobotsurface2_seed_08.model
# pLF_data_35_starlightcurves_seed_08.model
# pLF_data_36_strawberry_seed_08.model
# pLF_data_37_symbols_seed_08.model
# pLF_data_38_twoleadecg_seed_08.model
# pLF_data_39_wafer_seed_08.model
# pLF_data_00_cbf_seed_09.model
# pLF_data_01_diatomsizereduction_seed_09.model
# pLF_data_02_distalphalanxoutlineagegroup_seed_09.model
# pLF_data_03_distalphalanxtw_seed_09.model
# pLF_data_04_earthquakes_seed_09.model
# pLF_data_05_ecg5000_seed_09.model
# pLF_data_06_ecgfivedays_seed_09.model
# pLF_data_07_fordb_seed_09.model
# pLF_data_08_freezerregulartrain_seed_09.model
# pLF_data_09_freezersmalltrain_seed_09.model
# pLF_data_10_gunpoint_seed_09.model
# pLF_data_11_gunpointagespan_seed_09.model
# pLF_data_12_gunpointmaleversusfemale_seed_09.model
# pLF_data_13_gunpointoldversusyoung_seed_09.model
# pLF_data_14_ham_seed_09.model
# pLF_data_15_handoutlines_seed_09.model
# pLF_data_16_insectepgregulartrain_seed_09.model
# pLF_data_17_insectepgsmalltrain_seed_09.model
# pLF_data_18_italypowerdemand_seed_09.model
# pLF_data_19_middlephalanxoutlineagegroup_seed_09.model
# pLF_data_20_middlephalanxoutlinecorrect_seed_09.model
# pLF_data_21_middlephalanxtw_seed_09.model
# pLF_data_22_mixedshapesregulartrain_seed_09.model
# pLF_data_23_motestrain_seed_09.model
# pLF_data_24_phalangesoutlinescorrect_seed_09.model
# pLF_data_25_plane_seed_09.model
# pLF_data_26_powercons_seed_09.model
# pLF_data_27_proximalphalanxoutlineagegroup_seed_09.model
# pLF_data_28_proximalphalanxoutlinecorrect_seed_09.model
# pLF_data_29_proximalphalanxtw_seed_09.model
# pLF_data_30_selfregulationscp1_seed_09.model
# pLF_data_31_slope_seed_09.model
# pLF_data_32_smoothsubspace_seed_09.model
# pLF_data_33_sonyaiborobotsurface1_seed_09.model
# pLF_data_34_sonyaiborobotsurface2_seed_09.model
# pLF_data_35_starlightcurves_seed_09.model
# pLF_data_36_strawberry_seed_09.model
# pLF_data_37_symbols_seed_09.model
# pLF_data_38_twoleadecg_seed_09.model
# pLF_data_39_wafer_seed_09.model

# %%
results.shape
# Out:
# torch.Size([40, 10, 2])

# %%
for N_selected_seeds in [3,5]:
    re_temp = torch.nan_to_num(results, nan=-10000.)
    values, indices = torch.topk(re_temp[:,:,0], N_selected_seeds, dim=1, largest=True, sorted=True)
    selected_results = results.gather(1, indices.unsqueeze(-1).expand(-1, -1, 2))
    selected_test_mean = selected_results[:,:,-1].mean(1)
    selected_test_std = selected_results[:,:,-1].std(1)
    selected_test_results = torch.cat([selected_test_mean.unsqueeze(-1), selected_test_std.unsqueeze(-1)], dim=1)
    
    np.savetxt(f"./evaluation/top_{N_selected_seeds}_LPF_acc.txt", selected_test_results.numpy(), delimiter="\t", fmt='%.5f')
